# %% [markdown]
# # KDE plot is just a smoother version of histograms

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df = sns.load_dataset('penguins')
sdf = df.loc[0:70]

# %%
sns.kdeplot(
    sdf,
    x='bill_length_mm',
    y='body_mass_g',
    hue='island',
    bw_adjust=0.6,
    fill=True, #NOTE: this is depreciated version shade=True
    multiple='stack'
    )
plt.show()

# %%
sns.kdeplot(data=sdf , x='bill_length_mm', hue='species', fill=True,)
plt.show()
